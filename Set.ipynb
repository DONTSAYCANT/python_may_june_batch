# %%
a = {1,2,3}

print(a)

print(type(a))

print(len(a))
# Out:
# {1, 2, 3}
# <class 'set'>
# 3

# %%
#Empty set creation  ************

a = {}

print(a)

print(type(a))
# Out:
# {}
# <class 'dict'>

# %%
a = set()

print(a)

print(type(a))
# Out:
# set()
# <class 'set'>

# %%
a = {1,2,3,55}

print(a)

print(type(a))
# Out:
# {1, 2, 3, 55}
# <class 'set'>

# %%
#Set doesnt allow duplicates

Li1 = [1,1,1,2,2,3,4,5,5,5]

print(Li1)
# Out:
# [1, 1, 1, 2, 2, 3, 4, 5, 5, 5]

# %%
se1 = {1,1,1,2,2,3,4,5,5,5}

print(se1)
# Out:
# {1, 2, 3, 4, 5}

# %%
#No indexing or no ordering

se1 = {1,1,1,2,2,3,4,5,5,5}

print(se1[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-a5fb3384f556> in <module>
#       3 se1 = {1,1,1,2,2,3,4,5,5,5}
#       4
# ----> 5 print(se1[0])
#       6
#
# TypeError: 'set' object is not subscriptable

# %%
#Methods

#Add

se1 = {1,1,1,2,2,3,4,5,5,5}
se1.add(100)

print(se1)

se1.add(5)

print(se1)

se1.add("python")
print(se1)
# Out:
# {1, 2, 3, 4, 5, 100}
# {1, 2, 3, 4, 5, 100}
# {1, 2, 3, 4, 5, 100, 'python'}

# %%
#update

se1 = {1,2,3,4}
se2 = {4,5,6,7}
se1.update(se2)
print(se1)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
#Set does not support + operator
se1 = {1,2,3,4}
se2 = {4,5,6,7}
se3 = se1 + se2
print(se1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-50338845c8f8> in <module>
#       1 se1 = {1,2,3,4}
#       2 se2 = {4,5,6,7}
# ----> 3 se3 = se1 + se2
#       4 print(se1)
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
#clear

se1 = {1,2,3,4}
se1.clear()
print(se1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-d35fd13d55d6> in <module>
#       2
#       3 se1 = {1,2,3,4}
# ----> 4 se1.clear(1)
#       5 print(se1)
#
# TypeError: clear() takes no arguments (1 given)

# %%
#Remove

se1 = {1,2,3,4}
se1.remove(1)

print(se1)

se1.remove(0)

print(se1)
# Out:
# {2, 3, 4}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-4a25c7e1282a> in <module>
#       6 print(se1)
#       7
# ----> 8 se1.remove(0)
#       9
#      10 print(se1)
#
# KeyError: 0

# %%
#discard #Will not throuw error for unavailable element

se1 = {1,2,3,4}
se1.discard(1)

print(se1)

se1.discard(0)

print(se1)
# Out:
# {2, 3, 4}
# {2, 3, 4}

# %%
#pop #It will remove randomly element

se1 = {1,2,3,3}

se1.pop()

print(se1)

se1.pop()

print(se1)
# Out:
# {2, 3}
# {3}

# %%
#copy

se1 = {1,2,3}
se2 = se1.copy()

print(se2)
# Out:
# {1, 2, 3}

# %%
#Union

se1 = {1,2,3,4}
se2 = {5,6,7,1,2}

se3 = se1.union(se2)
print(se3)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
#intersection

se1 = {1,2,3,4}
se2 = {5,6,7,1,2}

se3 = se1.intersection(se2)
print(se1)
print(se3)
# Out:
# {1, 2, 3, 4}
# {1, 2}

# %%
#intersection update

se1 = {1,2,3,4}
se2 = {5,6,7,1,2}

se1.intersection_update(se2)
print(se1)
# Out:
# {1, 2}

# %%
#symmentric difference  (AUB) - (AnB)


se1 = {1,2,3,4}
se2 = {5,6,7,1,2}

se3 = se1.symmetric_difference(se2)
print(se3)
# Out:
# {3, 4, 5, 6, 7}

# %%
se1 = {1,2,3,4}
se2 = {5,6,7,1,2}

se1.symmetric_difference_update(se2)
print(se1)
# Out:
# {3, 4, 5, 6, 7}

# %%
#Duplicate removal

Li1 = [1,2,3,1,2,3,2]

print(list(set(Li1)))

print(set(Li1))
# Out:
# [1, 2, 3]
# {1, 2, 3}

# %%
#https://www.w3schools.com/python/python_ref_set.asp

# %%
x = {"a", "b", "c"}
y = {"f", "d", "a"}
z = {"c", "d", "e"}

result = x.union(y, z)

print(result)
# Out:
# {'a', 'c', 'b'}
# {'e', 'c', 'b', 'd', 'f', 'a'}

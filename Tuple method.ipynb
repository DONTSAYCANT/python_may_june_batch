# %%
#https://www.w3schools.com/python/python_ref_tuple.asp

# %%
a = (1,2,3)

print(a)
print(type(a))
# Out:
# (1, 2, 3)
# <class 'tuple'>

# %%
#Indexed or ordered

print(a[2])
# Out:
# 3

# %%
#Immutable

a[1] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-660a25dfe6c1> in <module>
#       1 #Immutable
#       2
# ----> 3 a[1] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(a.count(1))
# Out:
# 1

# %%
print(a.index(3))
# Out:
# 2

# %%
#tuple empty 


a = ()
print(a)
print(type(a))

a = tuple()
print(a)
# Out:
# ()
# <class 'tuple'>

# %%
#List to tuple
a = [1,2,3,4]

print(a)
print(type(a))

b = tuple(a)

print(b)
print(type(b))
# Out:
# [1, 2, 3, 4]
# <class 'list'>
# (1, 2, 3, 4)
# <class 'tuple'>
